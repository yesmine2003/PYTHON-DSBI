# %% [markdown]
# Answer each question by doing some operations with Python. Put conclusion in the comments

# %% [markdown]
# 1.1 For the following variables, use the function type() from Python to check the data type for the variables.

# %%
x1 = 1.1
x2 = "Monday"
x3 = "1.1"
x4 = True
x5 = "True"
x6 = -1

# %%
print(type(x1))
print(type(x2))
print(type(x3))
print(type(x4))
print(type(x5))
print(type(x6))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'str'>
# <class 'int'>

# %%
type(x1)
type(x2)
type(x3)# il prend que le type du dernier !!!
# Out:
# str

# %% [markdown]
# 1.2 What is the difference between variables x1 and x3?

# %%
# type(x1) is float (546.25)
# Out:
# float

# %%
#and type(x3) is string (exp:gdsvdiubc)
# Out:
# str

# %% [markdown]
# 1.3 What happens if you subtract x3 from x1?

# %%
x3-x1 #it will not work (not the same type)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 x3-x1
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %% [markdown]
# 1.4 What is the difference between variables x4 and x5?

# %%
x4-x5 #it will not work (not the same type)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 x4-x5
#
# TypeError: unsupported operand type(s) for -: 'bool' and 'str'

# %%
it can be true or false only
# Out:
# bool

# %%
it is true but it is a string so it is considered as a simple text whith no meaning
# Out:
# str

# %% [markdown]
# 1.5 What happens if you subtract x5 from x4?

# %%
it will not work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-08285411ce0c> in <module>
# ----> 1 a=x5-x4
#       2 print(a)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'bool'

# %% [markdown]
# 2.1 To gather input from the user, we can use the function input(message), where “message” is a meaningful message of type str and will be displayed to the user.

# %%
# Out:
# Please enter an integer number: 2
# Please enter another integer number: 3

# %% [markdown]
# Question 1: Print the values of the two variables? As you might have noticed, data type of x1 and x2 is string. Even though we entered integers, the input function converts them into string by default. Now we do some data type conversion from string to integers:

# %%
#Print the values of the two variables
x1= int(input('Add the first variable')) #on one line
x2= input('Add the second variable')
#conversion from string to integers
x2=int(x2)
# Out:
# Add the first variable 4
# Add the second variable 5

# %% [markdown]
# Question 2: What is the data type of x1 and x2? Now perform simple comparisons between x1 and x2:
#
# Check if the two variables are equal?
#
# Check if x1 is greater than x2?
#
# Check if x2 is greater than x1?
#
# Check if x1 is not equal to x2?
#
# Store the difference between the two variables x1 and x2 in another variable x3 (subtract the smaller number from the larger number).
#
# Increment the smaller of the two variables (x1 and x2) with the difference.Use the shorthand addition operator for the same. Again check if x1 and x2 are equal or not?

# %%
print(type(x1))
# Out:
# <class 'int'>

# %%
print(type(x2))
# Out:
# <class 'int'>

# %%
x1==x2
# Out:
# False

# %%
#x1==x2
# Out:
# False

# %%
x1>x2
# Out:
# False

# %%
x1<x2
# Out:
# True

# %%
x1!=x2
# Out:
# True

# %%
x1-x2
# Out:
# -1

# %%
L1=[2,3]

# %% [markdown]
# LISTES

# %%
type(L1)
# Out:
# list

# %%
#Create an empty list
L2=[]

# %%
#see the type
type (L2)
# Out:
# list

# %%
#Create a list that contain EDC
L3=list("EDC")

# %%
#Print the elements of the list
L3
# Out:
# ['E', 'D', 'C', '!', '!']

# %%
#Print only the second value of the list
L3[2]
# Out:
# 'C'

# %%
#Add (a chaque fois que je réexecute ça ajoute encore)
L3.append("!")

# %%
L3
# Out:
# ['E', 'D', 'C', '!', '!', '!', '!', '!']

# %%
len(L3)
# Out:
# 8

# %%
#reverse the elements of the list
L3.reverse()

# %%
L3
# Out:
# ['!', '!', '!', '!', '!', 'C', 'D', 'E']

# %%
L4=[1,2,3,4]

# %%
sum(L4)
# Out:
# 10

# %%
#list of lists: chaque liste est de type integer et lists et de type list of lists
lists=[[1,2,3],[4,5,6],[7,8,9]]

# %%
#afficher le premier element de la list 
lists[0]
# Out:
# [1, 2, 3]

# %%
#afficher le second element de la deuxième sous liste
lists[1][2]
# Out:
# 6

# %% [markdown]
# DICTIONARY

# %%
#Introducing a dictionary: keys MUST be unique
d={1:"EDC1",
  2:"EDC2"}

# %%
d
# Out:
# {1: 'EDC1', 2: 'EDC2'}

# %%
#Introducing a dictionary: using a unique string key
d1={"Fac1":"IHEC",
   "Fac2":"EDC"}

# %%
d1
# Out:
# {'Fac1': 'IHEC', 'Fac2': 'EDC'}

# %% [markdown]
# TUPLES: sismilar to list but once a tuple is created, you cannot add, delete, replace, reorder elements! (NOT MODIFIABLE)
# It's used for security issues: the difference is ()

# %%
t=(1,2,3)

# %%
type(t)
# Out:
# tuple

# %%
#check if an element exists (on peut faire de même pour les listes)
5 in t
# Out:
# False

# %%
#tu ne peux pas ajouter
t.append("!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 #tu ne peux pas ajouter
# ----> 2 t.append("!")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# SETS: We can just delete or add BUT YOU CAN NOT MODIFY also (HAS NO DUPLICATE)

# %%
s={"a","b","c","c"}

# %%
s #as you can see it remove the duplicate item
# Out:
# {'a', 'b', 'c'}
